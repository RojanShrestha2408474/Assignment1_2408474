# %%
#Name:Rojan Nath Shrestha
#Student ID:2408474

# %%
#importing google drvie into google collab
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Assignment1
# Out:
# /content/drive/MyDrive/Assignment1

# %%
#checking the file directory
# !ls
# Out:
# 2408474_Rojan_Shresthaipynb.ipynb  south_asia_data.csv	WHR-2024-5CS037.csv

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from scipy import stats
import matplotlib.pyplot as plt

# %% [markdown]
# **PROBLEM 1**

# %%
#reading the csv file World
df=pd.read_csv('WHR-2024-5CS037.csv')

# %%
#display the 10 first rows
df.head(10)
# Out:
#   Country name  score  Log GDP per capita  Social support  \
# 0      Finland  7.741               1.844           1.572
# 1      Denmark  7.583               1.908           1.520
# 2      Iceland  7.525               1.881           1.617
# 3       Sweden  7.344               1.878           1.501
# 4       Israel  7.341               1.803           1.513
# 5  Netherlands  7.319               1.901           1.462
# 6       Norway  7.302               1.952           1.517
# 7   Luxembourg  7.122               2.141           1.355
# 8  Switzerland  7.060               1.970           1.425
# 9    Australia  7.057               1.854           1.461
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.695                         0.859       0.142
# 1                    0.699                         0.823       0.204
# 2                    0.718                         0.819       0.258
# ...

# %% [markdown]
# 1.2 Identify the number of rows and columns in the dataset.

# %%
#getting the number of rows and column
num_rows=df.shape[0]
print(f"Number of rows:{num_rows}")
num_column=df.shape[1]
print(f"Number of columns:{num_column}")
# Out:
# Number of rows:143
# Number of columns:9

# %% [markdown]
# 1.3 listing all the columns and their data types

# %%
# display the column names and data types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 143 entries, 0 to 142
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Country name                  143 non-null    object
#  1   score                         143 non-null    float64
#  2   Log GDP per capita            140 non-null    float64
#  3   Social support                140 non-null    float64
#  4   Healthy life expectancy       140 non-null    float64
#  5   Freedom to make life choices  140 non-null    float64
#  6   Generosity                    140 non-null    float64
#  7   Perceptions of corruption     140 non-null    float64
#  8   Dystopia + residual           140 non-null    float64
# dtypes: float64(8), object(1)
# memory usage: 10.2+ KB

# %% [markdown]
# Basic Statiscs:
# 1. Calculate the mean, median, and standard deviation for the Score column.

# %%
#calculating the mean, median , standarad deviation of the Score column
mean_score=df['score'].mean()
median_score=df['score'].median()
std_dev_score=df['score'].std()

print(f"Mean Score:{mean_score}")
print(f"Median Score:{median_score}")
print(f"Standard Deviation Score:{std_dev_score}")
# Out:
# Mean Score:5.52758041958042
# Median Score:5.785
# Standard Deviation Score:1.1707165099442995

# %% [markdown]
# 2. Identify the country with the highest and lowest happiness scores.

# %%
#identifying the country with highest and lowest happiness scores
highest_score_country=df.loc[df['score'].idxmax(),'Country name']
lowest_score_country=df.loc[df['score'].idxmin(),'Country name']

print(f"Country with the highest happiness score : {highest_score_country}")
print(f"Country with the lowest happiness score : {lowest_score_country}")
# Out:
# Country with the highest happiness score : Finland
# Country with the lowest happiness score : Afghanistan

# %% [markdown]
# 1. Check if there are any missing values in the dataset. If so, display the total count for each column.

# %%
#check for the missing value
missing_value=df.isnull().sum()
print(missing_value)
# Out:
# Country name                    0
# score                           0
# Log GDP per capita              3
# Social support                  3
# Healthy life expectancy         3
# Freedom to make life choices    3
# Generosity                      3
# Perceptions of corruption       3
# Dystopia + residual             3
# dtype: int64

# %% [markdown]
# Filter and Sorting:
# Filter the dataset to show only the countries with a Score greater than 7.5.

# %%
#Filter and SOtrtering
filtered_df=df[df['score']>7.5]
filtered_df
# Out:
#   Country name  score  Log GDP per capita  Social support  \
# 0      Finland  7.741               1.844           1.572
# 1      Denmark  7.583               1.908           1.520
# 2      Iceland  7.525               1.881           1.617
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.695                         0.859       0.142
# 1                    0.699                         0.823       0.204
# 2                    0.718                         0.819       0.258
#
#    Perceptions of corruption  Dystopia + residual
# 0                      0.546                2.082
# 1                      0.548                1.881
# 2                      0.182                2.050

# %% [markdown]
# 2.For the filtered dataset - Sort the dataset by GDP per Capita in descending order and display the
# top 10 rows.

# %%
#Sort the dataset
sorted_df = df.sort_values(by=['Log GDP per capita'], ascending=False)
sorted_df.head(10)
# Out:
#                  Country name  score  Log GDP per capita  Social support  \
# 7                  Luxembourg  7.122               2.141           1.355
# 16                    Ireland  6.838               2.129           1.390
# 29                  Singapore  6.523               2.118           1.361
# 21       United Arab Emirates  6.733               1.983           1.164
# 8                 Switzerland  7.060               1.970           1.425
# 6                      Norway  7.302               1.952           1.517
# 22              United States  6.725               1.939           1.392
# 85  Hong Kong S.A.R. of China  5.316               1.909           1.184
# 1                     Denmark  7.583               1.908           1.520
# 5                 Netherlands  7.319               1.901           1.462
#
#     Healthy life expectancy  Freedom to make life choices  Generosity  \
# 7                     0.708                         0.801       0.146
# ...

# %% [markdown]
#  Adding New Columns:
# 1. Create a new column called Happiness Category that categorizes countries into three categories
# based on their Score:

# %%
#adding new column to the dataframe
def category_happiness(score):
  if score<4:
    return 'Low'
  elif score <=6:
    return 'Medium'
  else:
    return 'High'

df['Happiness_Category']=df['score'].apply(category_happiness)
df.head()
# Out:
#   Country name  score  Log GDP per capita  Social support  \
# 0      Finland  7.741               1.844           1.572
# 1      Denmark  7.583               1.908           1.520
# 2      Iceland  7.525               1.881           1.617
# 3       Sweden  7.344               1.878           1.501
# 4       Israel  7.341               1.803           1.513
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.695                         0.859       0.142
# 1                    0.699                         0.823       0.204
# 2                    0.718                         0.819       0.258
# 3                    0.724                         0.838       0.221
# 4                    0.740                         0.641       0.153
#
#    Perceptions of corruption  Dystopia + residual Happiness_Category
# 0                      0.546                2.082               High
# ...

# %%
#Data Visualization

top_10=df.sort_values(by=['score'],ascending=False).head(10)


#plotting the bar graph using Seaborn
plt.figure(figsize=(12,6))
sns.barplot(x='Country name',y='score',data=top_10, palette='viridis',hue='Country name')
plt.title("Top 10 Happiest Countries by Score", fontweight='bold')
plt.xlabel('Country', fontweight='bold')
plt.ylabel('Happiness Score', fontweight='bold')
plt.xticks(rotation=0, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# Line Plot: Plot the top 10 unhappiest countries by Score using a Line chart.

# %%
#Line plot of the unhappiest country by Score
bottom_10=df.sort_values(by=['score'],ascending=True).head(10)

#Line Plot
plt.figure(figsize=(12, 6))
sns.lineplot(x='Country name',y='score',data=bottom_10,marker='o',color='red')
plt.title("Unhappiest Countries by Score", fontweight="bold")
plt.xlabel('Country', fontweight='bold')
plt.ylabel('Happiness Score', fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# Plot a histogram for the Score column to show its distribution and also interpret.

# %%
#Plotting a histogram

plt.figure(figsize=(10,6))
sns.histplot(df['score'], bins=10, kde=True, color='darkseagreen')
plt.title("Distribution of Happiness Score")
plt.xlabel("Happiness Score")
plt.ylabel("Frequency")
plt.tight_layout()
plt.show()

# %% [markdown]
# • Scatter Plot: Plot a scatter plot between GDP per Capita and Score to visualize their relationship.

# %%
#Scatter Plot

plt.figure(figsize=(8,6))
sns.scatterplot(x='Log GDP per capita', y='score', data=df,hue='score', palette='husl')
plt.title("Relationship between GDP per Capita and Happiness Score", fontweight="bold")
plt.xlabel("Long GDP per Capita", fontweight="bold")
plt.ylabel("Happiness Score", fontweight="bold")
plt.tight_layout()
plt.show()

# %% [markdown]
# PROBLEM 2

# %% [markdown]
# 1. Define the countries in South Asia with a list for example:
# south asian countries = ["Afghanistan", "Bangladesh", "Bhutan", "India",
#
# "Maldives", "Nepal", "Pakistan", "Srilanka"]

# %%
# list of South Asian Countries
south_asian_countries = ["Afghanistan", "Bangladesh", "Bhutan", "India","Maldives", "Nepal", "Pakistan", "Sri Lanka"]

south_asia_df=df[df['Country name'].isin(south_asian_countries)]

south_asia_df
# Out:
#     Country name  score  Log GDP per capita  Social support  \
# 92         Nepal  5.158               0.965           0.990
# 107     Pakistan  4.657               1.069           0.600
# 125        India  4.054               1.166           0.653
# 127    Sri Lanka  3.898               1.361           1.179
# 128   Bangladesh  3.886               1.122           0.249
# 142  Afghanistan  1.721               0.628           0.000
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 92                     0.443                         0.653       0.209
# 107                    0.321                         0.542       0.144
# 125                    0.417                         0.767       0.174
# 127                    0.586                         0.583       0.144
# 128                    0.513                         0.775       0.140
# 142                    0.242                         0.000       0.091
#
# ...

# %% [markdown]
# Save the filtered dataframe as separate CSV files for future use.

# %%
#Saving the filtered dataset in different CSV
south_asia_df.to_csv('south_asia_data.csv', index=False)

# %% [markdown]
# Task-2

# %% [markdown]
# Using the SouthAsia DataFrame, create a new column called Composite Score that combines the
# following metrics:
#
# Composite Score = 0.40 × GDP per Capita + 0.30 × Social Support
#
# + 0.30 × Healthy Life Expectancy

# %%
south_asia_df.loc[:,'Composite Score']= (
    0.40*south_asia_df['Log GDP per capita']+
    0.30*south_asia_df['Social support']+
    0.30*south_asia_df['Healthy life expectancy']
)

south_asia_df
# Out:
#     Country name  score  Log GDP per capita  Social support  \
# 92         Nepal  5.158               0.965           0.990
# 107     Pakistan  4.657               1.069           0.600
# 125        India  4.054               1.166           0.653
# 127    Sri Lanka  3.898               1.361           1.179
# 128   Bangladesh  3.886               1.122           0.249
# 142  Afghanistan  1.721               0.628           0.000
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 92                     0.443                         0.653       0.209
# 107                    0.321                         0.542       0.144
# 125                    0.417                         0.767       0.174
# 127                    0.586                         0.583       0.144
# 128                    0.513                         0.775       0.140
# 142                    0.242                         0.000       0.091
#
# ...

# %% [markdown]
#  2 Rank the South Asian countries based on the Composite Score in descending order.*italicized text*

# %%
#ranking the South Asian countries on composite score
ranked_south_asia=south_asia_df.sort_values(by=['Composite Score'],ascending=False)

ranked_south_asia[['Country name', 'Composite Score']]
# Out:
#     Country name  Composite Score
# 127    Sri Lanka           1.0739
# 92         Nepal           0.8159
# 125        India           0.7874
# 107     Pakistan           0.7039
# 128   Bangladesh           0.6774
# 142  Afghanistan           0.3238

# %% [markdown]
# 3. Visualize the top 5 countries using a horizontal bar chart showing the Composite Score.

# %%
#Visualize top 5 countries

top_5=ranked_south_asia.head(5)

plt.figure(figsize=(10,6))
sns.barplot(x='Composite Score',y='Country name',data=top_5,orient='h',color='darkseagreen')
plt.title("Top 5 South Asian Countries by Composite Score")
plt.xlabel("Composite Score")
plt.ylabel("Country")
plt.tight_layout()
plt.show()

# %% [markdown]
# 4  Discuss whether the rankings based on the Composite Score align with the original Score - support your
# discussion with some visualization plot.

# %%
#problem 4
#Comparison
comparison_df=south_asia_df[['Country name','score','Composite Score']]

comparison_df = comparison_df.sort_values(by=['Composite Score'],ascending=False)

comparison_df
# Out:
#     Country name  score  Composite Score
# 127    Sri Lanka  3.898           1.0739
# 92         Nepal  5.158           0.8159
# 125        India  4.054           0.7874
# 107     Pakistan  4.657           0.7039
# 128   Bangladesh  3.886           0.6774
# 142  Afghanistan  1.721           0.3238

# %% [markdown]
# Data Visualization

# %%
#Data Visualization
plt.figure(figsize=(10,6))
sns.scatterplot(x='score',y='Composite Score', data=comparison_df,hue='Country name')
plt.title("Relationship between Score and Composite Score for South Asian Countries")
plt.xlabel("Original Score")
plt.ylabel("Composite Score")
plt.tight_layout()
plt.show()

# %% [markdown]
# Task-3

# %% [markdown]
# Identify outlier countries in South Asia based on their Score and GDP per Capita.

# %%
#Identify outlier countries in South Asia based on Sore and GDP

Q1_score=south_asia_df['score'].quantile(0.25)
Q3_score=south_asia_df['score'].quantile(0.75)
IQR_score=Q3_score-Q1_score


Q1_gdp=south_asia_df['Log GDP per capita'].quantile(0.25)
Q3_gdp=south_asia_df['Log GDP per capita'].quantile(0.75)
IQR_gdp=Q3_gdp-Q1_gdp

upper_bound_score=Q3_score+1.5*IQR_score
lower_bound_score=Q1_score-1.5*IQR_score
upper_bound_gdp=Q3_gdp+1.5*IQR_gdp
lower_bound_gdp=Q1_gdp-1.5*IQR_gdp

#itendfiyng outliers
outliers=south_asia_df[
    (south_asia_df['score']>upper_bound_score) | (south_asia_df['score']<lower_bound_score) |
    (south_asia_df['Log GDP per capita']>upper_bound_gdp) | (south_asia_df['Log GDP per capita']<lower_bound_gdp)
]

outliers[['Country name','score','Log GDP per capita']]
# Out:
#     Country name  score  Log GDP per capita
# 142  Afghanistan  1.721               0.628

# %% [markdown]
# 2 Define outliser using the 1.5*IQR rle
#
# The 1.5 * IQR rule defines outlier as dat apoints that fall outside the boundaries
# Upper bound Q3+1.5*IQR
# Lower bound Q1-1.5*IQR
#
# where Q1 is the first quartile and Q3 is the third quartile and IQR is the interquartile range Q3-Q1

# %% [markdown]
# 3. Create a scatter plot with GDP per Capita on the x-axis and Score on the y-axis, highlighting outliers
# in a different color.

# %%
plt.figure(figsize=(10, 6))

#Plotting all South Asian countries
sns.scatterplot(x='Log GDP per capita', y='score', data=south_asia_df, color='blue', label='South Asian Countries')

#Identifying and highlighting outliers
outliers = south_asia_df[
    (south_asia_df['score'] > upper_bound_score) | (south_asia_df['score'] < lower_bound_score) |
    (south_asia_df['Log GDP per capita'] > upper_bound_gdp) | (south_asia_df['Log GDP per capita'] < lower_bound_gdp)
]
sns.scatterplot(x='Log GDP per capita', y='score', data=outliers, color='red', label='Outliers')
plt.title('GDP per Capita vs. Happiness Score (South Asia)', fontsize=14, fontweight='bold')
plt.xlabel('Log GDP per Capita', fontsize=12)
plt.ylabel('Happiness Score', fontsize=12)
plt.legend()
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %% [markdown]
# 4. Discuss the characteristics of these outliers and their potential impact on regional averages:
#
# Characteristics of Outliers:
#
# The outliers in this report are countries with the highest or lowest score or GDP per capita compared to other South Asian Countries. They represent the data point that differs greatly from the normal patterns which has been observed within the dataset.
# The potential impact on the regional average are that the outlier countries can lead to bias in the statistical analyses and conclusion. They are able to have a significant impact on the regional averages and therefore it can lead to major impact on the happiness and development.
# They are also able to hide the underlying patterns within the data which makes it challenging to identify significant correlations between the variables.

# %% [markdown]
# Task 4

# %% [markdown]
# Choose two metrics (e.g., Freedom to Make Life Choices and Generosity) and calculate their correlation
# {pearson correlation} with the Score for South Asian countries.

# %%
#no1
correlation_freedom=south_asia_df['score'].corr(south_asia_df['Freedom to make life choices'], method='pearson')

correlation_genoristy=south_asia_df['score'].corr(south_asia_df['Generosity'], method='pearson')

print(f"Correlation between Score and Freedom to make life choices: {correlation_freedom}")
print(f"Correlation between Score and Generosity: {correlation_genoristy}")
# Out:
# Correlation between Score and Freedom to make life choices: 0.8005185224163315
# Correlation between Score and Generosity: 0.874512371253192

# %% [markdown]
# Create scatter plots with trendlines for these metrics against the Score.

# %%
#no2
#Scatter plot

plt.figure(figsize=(8,6))
sns.regplot(x='Freedom to make life choices',y='score',data=south_asia_df,color='darkseagreen')
plt.title('Scatter Plot with Tredine: Freedom to make life choice vs score')
plt.xlabel('Freedom to Make Life choices')
plt.ylabel('Happiness Score')
plt.tight_layout()
plt.show()

plt.figure(figsize=(8,6))
sns.regplot(x='Generosity',y='score',data=south_asia_df,color='darkseagreen')
plt.title('Scatter Plot with Tredine: Generosity vs score')
plt.xlabel('Generosity')
plt.ylabel('Happiness Score')
plt.tight_layout()
plt.show()

# %% [markdown]
# 3. Create scatter plots with trendlines for these metrics against the Score.
# Identifying Strongest and Weakest Relationships:
#
# In the above scatter plot the metrics with the highest absolute correlation coefficient examines a stronger relationship with Score and the metric with the lower absolute correlation coefficient suggests the weaker relationship with score. The mean that changes in the metrics are closely related with the changes in happiness score. Using the scatter we can visualize that the metric with the stronger relationship normally has a more defined trendline which indicates a clear pattern between the metric and the happiness score.

# %% [markdown]
# Task5-Gap Analyis

# %% [markdown]
# 1. Add a new column, GDP-Score Gap, which is the difference between GDP per Capita and the Score
# for each South Asian country.

# %%
#new column difference GDP and Score
south_asia_df.loc[:,'GDP-Score Gap']= south_asia_df['Log GDP per capita']-south_asia_df['score']

south_asia_df
# Out:
#     Country name  score  Log GDP per capita  Social support  \
# 92         Nepal  5.158               0.965           0.990
# 107     Pakistan  4.657               1.069           0.600
# 125        India  4.054               1.166           0.653
# 127    Sri Lanka  3.898               1.361           1.179
# 128   Bangladesh  3.886               1.122           0.249
# 142  Afghanistan  1.721               0.628           0.000
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 92                     0.443                         0.653       0.209
# 107                    0.321                         0.542       0.144
# 125                    0.417                         0.767       0.174
# 127                    0.586                         0.583       0.144
# 128                    0.513                         0.775       0.140
# 142                    0.242                         0.000       0.091
#
# ...

# %% [markdown]
# Rank the South Asian countries by this gap in both ascending and descending order.

# %%
#Rank the south Asian countries by gap
#by ascending
ascending_ranked=south_asia_df.sort_values(by=['GDP-Score Gap'],ascending=True)

ascending_ranked[['Country name','GDP-Score Gap']]
# Out:
#     Country name  GDP-Score Gap
# 92         Nepal         -4.193
# 107     Pakistan         -3.588
# 125        India         -2.888
# 128   Bangladesh         -2.764
# 127    Sri Lanka         -2.537
# 142  Afghanistan         -1.093

# %% [markdown]
# Rank the South Asian countries by this gap in both ascending and descending order.

# %% [markdown]
# 2. Rank the South Asian countries by this gap in both ascending and descending order.

# %%
descending_ranked=south_asia_df.sort_values(by=['GDP-Score Gap'],ascending=False)

descending_ranked[['Country name','GDP-Score Gap']]
# Out:
#     Country name  GDP-Score Gap
# 142  Afghanistan         -1.093
# 127    Sri Lanka         -2.537
# 128   Bangladesh         -2.764
# 125        India         -2.888
# 107     Pakistan         -3.588
# 92         Nepal         -4.193

# %% [markdown]
# 3 Highlight the top 3 countries with the largest positive and negative gaps using a bar chart.

# %%
#Highlight the top 3 countries with largest positive nad negativegaps


top_positive_gap = descending_ranked.head(3)
top_negative_gap = ascending_ranked.head(3)

plt.figure(figsize=(8, 6))
sns.barplot(x='Country name', y='GDP-Score Gap', data=top_positive_gap, color='darkseagreen')
plt.title('Top 3 Countries with Largest Positive GDP-Score Gaps')
plt.xlabel('Country')
plt.ylabel('GDP-Score Gap')
plt.tight_layout()
plt.show()

plt.figure(figsize=(8, 6))
sns.barplot(x='Country name', y='GDP-Score Gap', data=top_negative_gap, color='lightcoral')
plt.title('Top 3 Countries with Largest Negative GDP-Score Gaps')
plt.xlabel('Country')
plt.ylabel('GDP-Score Gap')
plt.show()

# %% [markdown]
# Qno4
# Analyze the reason behind these gaps and their implications for South Asian Countries
#
# Answer:
# The GDP-Score Gap represnets the difference between the country'sGDP per capita and its overall happiness. there are various factors that can contribute the gap such as:
# 1. Non-economic factors
# Hapiness is influenced  by many other non-economic factor such as social support, healthy life expectancy, freedom to make life choices, and perceptions of corruption.
#
# 2.Income inequality
# Even in countries with high GDP per capita the income inequality can lead to a major population to experience lower levels of well-being.
#
# Social and political factors
# social and political factors can negatively impact the happiness level even in the countries with relatively high GDP per capita
#
#
#
# Implications for South Asian Countries:
# The GDP-Score Gap has several implications for South Asian countries:
# 1. Policy Focus
# Governments should proritize policies that address not only the economic growth but also the non-economic factors that contribute to happiness such as social support and health and freedom
#
# 2. Sustainable devleopment
# Countries should pursue sustainable development pathways that balance economic growth with social and environmental considerations to ensure long-term well being for their citizens
#
#
#
# This gap has implications for how South Asian countries should approach development. They need to focus not just on making money but also on improving people's lives in other ways, like providing good healthcare and ensuring people feel safe and free. By addressing these broader aspects of well-being, countries can strive to reduce the gap between their economic performance and overall happiness, ultimately leading to a more fulfilling and prosperous society for their citizens.

# %% [markdown]
# Problem 3
# Comparitive Analysis

# %% [markdown]
# 1. Similar in Task - 1 of Problem 2 create a dataframe from middle eastern countries. For hint use the
# following list:
# middle east countries = [ "Bahrain", "Iran", "Iraq", "Israel", "Jordan",
# "Kuwait", "Lebanon", "Oman", "Palestine", "Qatar", "Saudi Arabia", "Syria",
#
# "United Arab Emirates", "Yemen"]

# %%
#creating the list of Middle Eastern Countries

middle_east_countries = [ "Bahrain", "Iran", "Iraq", "Israel", "Jordan","Kuwait", "Lebanon", "Oman", "Palestine", "Qatar", "Saudi Arabia", "Syria","United Arab Emirates", "Yemen"]

middle_east_df=df[df['Country name'].isin(middle_east_countries)]

middle_east_df
# Out:
#              Country name  score  Log GDP per capita  Social support  \
# 4                  Israel  7.341               1.803           1.513
# 12                 Kuwait  6.951               1.845           1.364
# 21   United Arab Emirates  6.733               1.983           1.164
# 27           Saudi Arabia  6.594               1.842           1.361
# 61                Bahrain  5.959                 NaN             NaN
# 91                   Iraq  5.166               1.249           0.996
# 99                   Iran  4.923               1.435           1.136
# 124                Jordan  4.186               1.262           0.983
# 132                 Yemen  3.561               0.671           1.281
# 141               Lebanon  2.707               1.377           0.577
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 4                      0.740                         0.641       0.153
# ...

# %% [markdown]
# 1. Descriptive Statistics:
# • Calculate the mean, Standard deviation of the score for both South Asia and Middle East.
# • Which region has higher happiness Scores on average?

# %%
#1
south_asian_mean=south_asia_df['score'].mean()
south_asian_std=south_asia_df['score'].std()

middle_east_mean=middle_east_df['score'].mean()
middle_east_std=middle_east_df['score'].std()

print(f"South Asian Mean Score: {south_asian_mean}, South Asian Standard Deviation: {south_asian_std}")
print(f"Middle East Mean Score: {middle_east_mean}, Middle East Standard Deviation: {middle_east_std}")
print("\n")

if south_asian_mean>middle_east_mean:
  print("South Asian countries have a higher mean score than Middle Eastern countries")
elif middle_east_mean>south_asian_mean:
  print("Middle Eastern countries have a higher mean score than South Asian countries")
else:
  print("Both regions have the same average happiness score")
# Out:
# South Asian Mean Score: 3.895666666666667, South Asian Standard Deviation: 1.1770690152521504
# Middle East Mean Score: 5.412100000000001, Middle East Standard Deviation: 1.5662011684327144
#
#
# Middle Eastern countries have a higher mean score than South Asian countries

# %% [markdown]
# 2. Top and Bottom Performers:
# • Identify the top 3 and bottom 3 countries in each region based on the score.
# • Plot bar charts comparing these charts.

# %%
#no2
south_asia_top3=south_asia_df.sort_values(by=['score'],ascending=False).head(3)
south_asia_bottom3=south_asia_df.sort_values(by=['score']).head(3)


middle_east_top3=middle_east_df.sort_values(by=['score'],ascending=False).head(3)
middle_east_bottom3=middle_east_df.sort_values(by=['score']).head(3)

top3_df = pd.concat([south_asia_top3, middle_east_top3])
top3_df['Region'] = ['South Asia'] * 3 + ['Middle East'] * 3

plt.figure(figsize=(10, 6))
sns.barplot(x='Country name', y='score', hue='Region', data=top3_df, palette='viridis')
plt.title('Top 3 Countries by Happiness Score')
plt.xlabel('Country')
plt.ylabel('Happiness Score')
plt.tight_layout()
plt.show()


bottom3_df = pd.concat([south_asia_bottom3, middle_east_bottom3])
bottom3_df['Region'] = ['South Asia'] * 3 + ['Middle East'] * 3


plt.figure(figsize=(10, 6))
sns.barplot(x='Country name', y='score', hue='Region', data=bottom3_df, palette='viridis')
plt.title('Bottom 3 Countries by Happiness Score')
plt.xlabel('Country')
plt.ylabel('Happiness Score')
plt.tight_layout()
plt.show()

# %% [markdown]
# 3. Metric Comparisons:
# • Compare key metrics like GDP per Capita, Social Support, and Healthy Life Expectancy
# between the regions using grouped bar charts.

# %%
#2
regional_averages = pd.DataFrame({
    'Region': ['South Asia', 'Middle East'],
    'Log GDP per capita': [south_asia_df['Log GDP per capita'].mean(), middle_east_df['Log GDP per capita'].mean()],
    'Social support': [south_asia_df['Social support'].mean(), middle_east_df['Social support'].mean()],
    'Healthy life expectancy': [south_asia_df['Healthy life expectancy'].mean(), middle_east_df['Healthy life expectancy'].mean()]
})


regional_averages_melted = regional_averages.melt(id_vars=['Region'], var_name='Metric', value_name='Average')


plt.figure(figsize=(10, 6))
sns.barplot(x='Metric', y='Average', hue='Region', data=regional_averages_melted, palette='viridis')
plt.title("Comparison of Key Metrics between South Asia and the Middle East")
plt.xlabel("Metric")
plt.ylabel("Average Value")
plt.tight_layout()
plt.show()

# %% [markdown]
# Which metrics show the largest disparity between the two regions?

# %%
disparity = regional_averages.set_index('Region').diff().abs().iloc[1]

largest_disparity_metric = disparity.idxmax()

print("\n")
print(f"The metric with the largest disparity between the two regions is: {largest_disparity_metric}")
# Out:
# The metric with the largest disparity between the two regions is: Social support

# %% [markdown]
# Happiness Disparity:
# • Compute the range (max - min) and coefficient of variation (CV) for Score in both regions.
# • Which region has greater variability in happiness?

# %%
#4

south_asia_range=south_asia_df['score'].max()-south_asia_df['score'].min()

middle_east_range=middle_east_df['score'].max()-middle_east_df['score'].min()


south_asia_cv=south_asia_df['score'].std() / south_asia_df['score'].mean()
middle_east_cv=middle_east_df['score'].std()/ middle_east_df['score'].mean()

print(f"Range of South Asian Countries: {south_asia_range}, Coefficient of Varivation: {south_asia_cv}")
print(f"Range of Middle Eastern Countries: {middle_east_range}, Coefficient of Variation: {middle_east_cv}")
print("\n")

if south_asia_cv>middle_east_cv:
  print("South Asian countries has greater variability in happiness")
elif middle_east_cv>south_east_cv:
  print("Middle eastern countries have greater varibility in happiness")
else:
  print("Both regions have the same variability in happiness")
# Out:
# Range of South Asian Countries: 3.4370000000000003, Coefficient of Varivation: 0.3021482883337427
# Range of Middle Eastern Countries: 4.634, Coefficient of Variation: 0.28938880812119405
#
#
# South Asian countries has greater variability in happiness

# %% [markdown]
# Correlation Analysis:
# • Analyze the correlation of Score with other metrics Freedom to Make Life Choices, and
# Generosity within each region.

# %%
# South Asia
south_asia_freedom_corr = south_asia_df['score'].corr(south_asia_df['Freedom to make life choices'])
south_asia_generosity_corr = south_asia_df['score'].corr(south_asia_df['Generosity'])

print(f"South Asia - Correlation with Freedom: {south_asia_freedom_corr}, Correlation with Generosity: {south_asia_generosity_corr}")

# Middle East
middle_east_freedom_corr = middle_east_df['score'].corr(middle_east_df['Freedom to make life choices'])
middle_east_generosity_corr = middle_east_df['score'].corr(middle_east_df['Generosity'])

print(f"Middle East - Correlation with Freedom: {middle_east_freedom_corr}, Correlation with Generosity: {middle_east_generosity_corr}")
# Out:
# South Asia - Correlation with Freedom: 0.8005185224163315, Correlation with Generosity: 0.874512371253192
# Middle East - Correlation with Freedom: 0.8632202433827544, Correlation with Generosity: 0.6275236536964182

# %% [markdown]
# Create scatter plots to visualize and interpret the relationships.

# %%
# South Asia
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.regplot(x='Freedom to make life choices', y='score', data=south_asia_df, color='darkseagreen')
plt.title('South Asia: Freedom vs. Score')

plt.subplot(1, 2, 2)
sns.regplot(x='Generosity', y='score', data=south_asia_df, color='royalblue')
plt.title('South Asia: Generosity vs. Score')

plt.tight_layout()
plt.show()

# Middle East
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.regplot(x='Freedom to make life choices', y='score', data=middle_east_df, color='darkseagreen')
plt.title('Middle East: Freedom vs. Score')

plt.subplot(1, 2, 2)
sns.regplot(x='Generosity', y='score', data=middle_east_df, color='royalblue')
plt.title('Middle East: Generosity vs. Score')

plt.tight_layout()
plt.show()

# %% [markdown]
# Interpreting the Scatter Plots:
#
# South Asia:
#
# Freedom vs. Score: You'll likely see an upward trend in the points, indicating a positive correlation between freedom to make life choices and happiness. The regression line will also slope upwards.
#
#
# Generosity vs. Score: The points might be more scattered, with a less clear trend, reflecting the weaker correlation between generosity and happiness.
#
#
#
# Middle East:
#
# Freedom vs. Score: Similar to South Asia, you'll likely see an upward trend, but it might be less pronounced compared to South Asia, indicating a moderate positive correlation.
#
#
#
# Generosity vs. Score: The points will likely be even more scattered than in South Asia, suggesting a very weak or no clear relationship between generosity and happiness.
# Overall:
#
# The scatter plots provide a visual representation of the correlation analysis. They help confirm the strength and direction of the relationships between happiness and the other metrics in each region. By observing the trends in the points and the regression lines, we can  gain a better understanding of how these variables are related.

# %%
def find_outliers_iqr(data, column):
    Q1 = data[column].quantile(0.25)
    Q3 = data[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = data[(data[column] < lower_bound) | (data[column] > upper_bound)]
    return outliers

south_asia_score_outliers = find_outliers_iqr(south_asia_df, 'score')
south_asia_gdp_outliers = find_outliers_iqr(south_asia_df, 'Log GDP per capita')


middle_east_score_outliers = find_outliers_iqr(middle_east_df, 'score')
middle_east_gdp_outliers = find_outliers_iqr(middle_east_df, 'Log GDP per capita')

print("Outlier Countries in South Asia based on Score:")
print(south_asia_score_outliers[['Country name', 'score']])
print("\nOutlier Countries in South Asia based on Log GDP per capita:")
print(south_asia_gdp_outliers[['Country name', 'Log GDP per capita']])
print("\nOutlier Countries in Middle East based on Score:")
print(middle_east_score_outliers[['Country name', 'score']])
print("\nOutlier Countries in Middle East based on Log GDP per capita:")
print(middle_east_gdp_outliers[['Country name', 'Log GDP per capita']])
# Out:
# Outlier Countries in South Asia based on Score:
#     Country name  score
# 142  Afghanistan  1.721
#
# Outlier Countries in South Asia based on Log GDP per capita:
#     Country name  Log GDP per capita
# 142  Afghanistan               0.628
#
# Outlier Countries in Middle East based on Score:
# Empty DataFrame
# Columns: [Country name, score]
# Index: []
#
# Outlier Countries in Middle East based on Log GDP per capita:
# Empty DataFrame
# Columns: [Country name, Log GDP per capita]
# Index: []

# %% [markdown]
# Plot these outliers and discuss their implications.

# %%
south_asia_all_outliers = pd.concat([south_asia_score_outliers, south_asia_gdp_outliers])

plt.figure(figsize=(8, 6))
sns.scatterplot(x='Log GDP per capita', y='score', data=south_asia_df, color='blue', label='South Asia Countries')
sns.scatterplot(x='Log GDP per capita', y='score', data=south_asia_all_outliers, color='red', label='Outliers')
plt.title("Outlier Countries in South Asia")
plt.xlabel('Log GDP per capita')
plt.ylabel('Happiness Score')
plt.legend()
plt.tight_layout()
plt.show()


middle_east_all_outliers = pd.concat([middle_east_score_outliers, middle_east_gdp_outliers])

plt.figure(figsize=(8, 6))
sns.scatterplot(x='Log GDP per capita', y='score', data=middle_east_df, color='blue', label='Middle East Countries')
sns.scatterplot(x='Log GDP per capita', y='score', data=middle_east_all_outliers, color='red', label='Outliers')
plt.title("Outlier Countries in Middle East")
plt.xlabel('Log GDP per capita')
plt.ylabel('Happiness Score')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# Discussion
# Discussion of Implications:
#
# The outlier countries have a unique social, economic and political factors that influences the happiness level which differs them from the other countries in the region. More importantly identifying these outliers can help in making policy to focus on specific countries and to understand the reason for their low happiness score. This steps can help in improving the well-being of the people in that region.

# %% [markdown]
# 7. Visualization:
# • Create boxplots comparing the distribution of Score between South Asia and the Middle East.
# • Interpret the key differences in distribution shapes, medians, and outliers.

# %%
#7

plt.figure(figsize=(8,6))

sns.boxplot(x='Region',y='score',data=pd.concat([south_asia_df.assign(Region='South Asia'),middle_east_df.assign(Region='Middle East')]))
plt.title('Distribution of Happiness Score in South Asia and Middle East')

plt.xlabel('Region')
plt.ylabel('Happiness Score')
plt.tight_layout()
plt.show()

# %% [markdown]
# 1.	Distribution Shapes
# South Asia:
# In the above boxplot it shows that happiness scores in South Asia is skewed towards lower values which means there are lot of countries with lower happiness scores in the region
# Middle East:
# In the given boxplot it indicates a more even distribution in the happiness score. This shows that there happiness score is evenly spread in the Middle East region.
#
# 2.	Medians;
# In the given box plot the median line for the Middle East is higher than that for South Asia which shows that Middle East has a higher happiness score compared to South Asia. This implies that the average country in the Middle East tends to have a higher happiness score than the average country in South Asia.
#
# 3.	Outliers
# In the given box plot we can visualize that there are few outliers with a very low score in south Asia but no outliers in the Middle East which implies that there is greater variability in happiness within the South Asia. This means that most South Asia countries might have happiness scores within a certain range, with unusually low happiness score, contributing to the variability. In the Middle East region there is absence of outliers which suggest a more consistent level of happiness across countries in the region.
#
# Overall this interpretation, these key differences suggest that while the Middle East might have an evenly higher overall level happiness score, South Asia shows the greater variability with some countries that experiences lower happiness.
#
#
#
# Conclusion
# This analysis examines the overall happiness and well-being of the South Asia and Middle East which focuses on identifying trends, disparities and potential influencing factors
